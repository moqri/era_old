# %%
import pandas as pd

# %%
df=pd.read_csv('../data/an.txt',sep='\t')
df.shape
# Out:
# (159, 790)

# %%
df.notna().sum().sort_values().iloc[-50:-1]
# Out:
# NF2L2_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)     82
# PIT1_HUMAN.H11MO.0.C Distance From Peak(sequence,strand,conservation)      82
# IRX3_HUMAN.H11MO.0.D Distance From Peak(sequence,strand,conservation)      82
# PO2F3_HUMAN.H11MO.0.D Distance From Peak(sequence,strand,conservation)     82
# SOX13_HUMAN.H11MO.0.D Distance From Peak(sequence,strand,conservation)     83
# LEF1_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)      83
# SRY_HUMAN.H11MO.0.B Distance From Peak(sequence,strand,conservation)       84
# PO3F1_HUMAN.H11MO.0.C Distance From Peak(sequence,strand,conservation)     84
# NKX61_HUMAN.H11MO.1.B Distance From Peak(sequence,strand,conservation)     85
# PO2F1_HUMAN.H11MO.0.C Distance From Peak(sequence,strand,conservation)     86
# HXD8_HUMAN.H11MO.0.D Distance From Peak(sequence,strand,conservation)      86
# FOXG1_HUMAN.H11MO.0.D Distance From Peak(sequence,strand,conservation)     87
# ...

# %%
df[[c for c in df.columns if c.startswith('NANOG_HUMAN.H11MO.0')]].notna().sum()
# Out:
# NANOG_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)    113
# dtype: int64

# %%
df[['NANOG_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)','PO5F1_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)','FOS_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)','JUN_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)']]
# Out:
#     NANOG_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)  \
# 0                                                  NaN
# 1    18(GCATTTCACATTCAATC,+,0.00),60(TACTACATATGAAA...
# 2    -93(ATTAACATAAGCATACA,-,0.00),4(ATGAGCAAAACAAA...
# 3    -66(AATTACACCTCAATAAA,-,0.00),-27(ACCTACATCACT...
# 4                        -15(CCCATTGATCTGTAACG,+,0.00)
# ..                                                 ...
# 154                      -49(CCTATTCACTTGCAGAA,+,0.00)
# 155  -47(ATTTACTTGTCTATAGC,-,0.00),56(TGTTTTGAAATGT...
# 156                                                NaN
# 157                      -91(TACTGAAAGTCAAAGAA,-,0.00)
# 158                                                NaN
#
#     PO5F1_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)  \
# 0                                                  NaN
# 1    19(CATTTCACATTCAATC,+,0.00),60(TACTACATATGAAAG...
# 2    -93(ATTAACATAAGCATAC,-,0.00),4(ATGAGCAAAACAAAA...
# ...

# %%
df
# Out:
#      PeakID (cmd=annotatePeaks.pl dmh.txt hg38 -m HOCOMOCOv11_full_HUMAN_mono_homer_format_0.0001.motif -cpu 16 -size 200)  \
# 0                                                   22
# 1                                                  142
# 2                                                    5
# 3                                                  131
# 4                                                   57
# ..                                                 ...
# 154                                                 36
# 155                                                117
# 156                                                 86
# 157                                                158
# 158                                                 80
#
#        Chr      Start        End Strand  Peak Score  Focus Ratio/Region Size  \
# 0     chr6   90008747   90008947      +           0                      NaN
# 1    chr10   72146674   72146874      +           0                      NaN
# ...

# %%
df
# Out:
#      PeakID (cmd=annotatePeaks.pl dmh.txt hg38 -m HOCOMOCOv11_full_HUMAN_mono_homer_format_0.0001.motif -cpu 16 -size 200)  \
# 0                                                   22
# 1                                                  142
# 2                                                    5
# 3                                                  131
# 4                                                   57
# ..                                                 ...
# 154                                                 36
# 155                                                117
# 156                                                 86
# 157                                                158
# 158                                                 80
#
#        Chr      Start        End Strand  Peak Score  Focus Ratio/Region Size  \
# 0     chr6   90008747   90008947      +           0                      NaN
# 1    chr10   72146674   72146874      +           0                      NaN
# ...
