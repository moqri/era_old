# %%
import pandas as pd

# %%
df=pd.read_csv('../data/an.txt',sep='\t')
df.shape
# Out:
# (107, 790)

# %%
df.notna().sum().sort_values().iloc[-50:-1]
# Out:
# ZSC22_HUMAN.H11MO.0.C Distance From Peak(sequence,strand,conservation)     82
# SP4_HUMAN.H11MO.1.A Distance From Peak(sequence,strand,conservation)       82
# ZBT17_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)     83
# ZN263_HUMAN.H11MO.1.A Distance From Peak(sequence,strand,conservation)     83
# ZN770_HUMAN.H11MO.0.C Distance From Peak(sequence,strand,conservation)     84
# ZFX_HUMAN.H11MO.1.A Distance From Peak(sequence,strand,conservation)       85
# KLF9_HUMAN.H11MO.0.C Distance From Peak(sequence,strand,conservation)      85
# SP3_HUMAN.H11MO.0.B Distance From Peak(sequence,strand,conservation)       86
# SP4_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)       86
# KLF3_HUMAN.H11MO.0.B Distance From Peak(sequence,strand,conservation)      86
# AP2D_HUMAN.H11MO.0.D Distance From Peak(sequence,strand,conservation)      86
# EGR2_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)      86
# ...

# %%
df[[c for c in df.columns if c.startswith('NANOG_HUMAN.H11MO.0')]].notna().sum()
# Out:
# NANOG_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)    34
# dtype: int64

# %%
df[['NANOG_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)',
    'PO5F1_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)',
    'FOS_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)',
    'JUN_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)',
   'Annotation']]
# Out:
#    NANOG_HUMAN.H11MO.0.A Distance From Peak(sequence,strand,conservation)  \
# 0                        64(CTTTTCATTGTAAAGGT,-,0.00)
# 1   -79(ATGTTTCTCATTCAAAT,+,0.00),-73(CTCATTCAAATG...
# 2                                                 NaN
# 3                                                 NaN
# 4   -39(AGCTCTGTTATGCAAAT,+,0.00),14(CCCATTCAAAGTC...
# 5                       -89(TCCATTATCATGTTAAG,+,0.00)
# 6   -45(TGATTACTCATTCAAAT,+,0.00),-39(CTCATTCAAATG...
# 7                                                 NaN
# 8   -82(TTCATTTTCATTTAAAT,+,0.00),-79(ATTTTCATTTAA...
# 9                        49(ATTAGCATTTCAGTAGA,-,0.00)
# 10  -69(ATCTCTGTTTTGCAAAT,+,0.00),66(ACTTTTGAAATTA...
# 11                      -48(TTCATTTTCATGTTGTT,+,0.00)
# 12                      -55(ATTAGCATCTCTAATTC,-,0.00)
# 13  -59(ACACTTCACATGCTAAT,+,0.00),-36(TCTTTTAACATT...
# 14  -56(GTCCTTCTTATTCTAAT,+,0.00),6(GTCCTTCTTATTCT...
# 15  35(AGCATTGAGGTGTAAAT,+,0.00),59(ATTTTCATGATAAT...
# ...
